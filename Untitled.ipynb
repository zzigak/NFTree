# %%
# Import
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
## import csv
df = pd.read_csv('Z0017_Tree.csv')

## drop rows without vigor
df = df.dropna(subset=['Vigor'])
df.head()
# Out:
#     PlotID  Year  SubplotID  TreeID  TreeStatus  DBH_Traditional  \
# 0  FEMC001  2018          1       1         NaN             34.2
# 1  FEMC001  2018          1       2         NaN             34.8
# 2  FEMC001  2018          1       3         NaN             45.2
# 3  FEMC001  2018          1       4         NaN             35.9
# 4  FEMC001  2018          1       5         NaN             33.5
#
#    DBH_Modified  DBH_Dendroband  CrownClass  TotalLength  ...  CauseofDamage3  \
# 0          34.2             NaN         3.0         26.2  ...             NaN
# 1          34.3             NaN         3.0         12.6  ...             NaN
# 2          45.2             NaN         3.0         26.7  ...             NaN
# 3          36.0             NaN         3.0         19.6  ...             NaN
# 4          33.5             NaN         2.0         25.8  ...             NaN
#
#    TreeHeight PreviousDBH  DiamChk  SpecialDamage2  SpecialDamage3  Aspect  \
# ...
